# %%
import pandas as pd

# Creazione del piano alimentare settimanale
piano_alimentare = []

# Dati per il piano alimentare
pasti_settimanali = {
    'Lunedì': {
        'Colazione': "100 g di fiocchi d'avena cotti con 250 ml di latte scremato, 1 banana affettata, 30 g di mandorle, 2 uova sode.",
        'Spuntino di metà mattina': "200 g di yogurt greco magro con 1 cucchiaio di miele, 1 mela.",
        'Pranzo': "150 g di petto di pollo alla griglia, 200 g di riso integrale cotto, verdure miste al vapore, 1 cucchiaio di olio d'oliva extravergine.",
        'Spuntino pomeridiano': "1 panino integrale con 50 g di fesa di tacchino, lattuga e pomodoro.",
        'Cena': "200 g di salmone al forno, 250 g di patate dolci al forno, insalata mista condita con olio d'oliva e aceto balsamico.",
        'Spuntino serale': "200 ml di latte scremato, 2 fette biscottate integrali con 30 g di ricotta magra."
    },
    'Martedì': {
        'Colazione': "Smoothie con 200 ml di latte scremato, 30 g di proteine in polvere, 1 tazza di frutti di bosco misti, 1 cucchiaio di burro di arachidi.",
        'Spuntino di metà mattina': "1 panino integrale con 50 g di bresaola, verdure fresche.",
        'Pranzo': "200 g di filetto di manzo alla griglia, 200 g di quinoa cotta, verdure grigliate (zucchine, melanzane), 1 cucchiaio di olio d'oliva.",
        'Spuntino pomeridiano': "1 barretta proteica (meno di 10 g di zuccheri), 1 yogurt magro.",
        'Cena': "200 g di tofu saltato con salsa di soia a basso contenuto di sodio, 200 g di noodles integrali, verdure miste (broccoli, funghi, peperoni).",
        'Spuntino serale': "200 ml di latte di mandorla non zuccherato, 30 g di noci."
    },
    # Aggiungi gli altri giorni della settimana nello stesso formato...
    'Mercoledì': {
        'Colazione': "2 fette di pane integrale tostato, 2 uova strapazzate con spinaci, 1 avocado affettato, pomodoro a fette.",
        'Spuntino di metà mattina': "1 pera, 30 g di anacardi.",
        'Pranzo': "150 g di petto di tacchino al forno, 200 g di pasta integrale con salsa di pomodoro e basilico, insalata mista.",
        'Spuntino pomeridiano': "200 g di yogurt greco magro con miele, frutti di bosco.",
        'Cena': "200 g di merluzzo al cartoccio con limone e prezzemolo, 200 g di riso basmati integrale, verdure al vapore (asparagi, carote).",
        'Spuntino serale': "200 ml di latte scremato, 2 fette biscottate integrali con 30 g di burro di arachidi."
    },
    'Giovedì': {
        'Colazione': "100 g di fiocchi d'avena con 250 ml di latte di soia, 1 mela a cubetti, 30 g di noci, 1 cucchiaino di cannella.",
        'Spuntino di metà mattina': "1 panino integrale con 50 g di prosciutto crudo magro, verdure fresche.",
        'Pranzo': "200 g di tonno alla griglia, 250 g di patate lesse condite con olio e prezzemolo, verdure grigliate (peperoni, zucchine).",
        'Spuntino pomeridiano': "1 barretta proteica, 1 yogurt magro.",
        'Cena': "200 g di lenticchie stufate, 200 g di couscous integrale, verdure miste al vapore.",
        'Spuntino serale': "200 ml di latte di soia, 30 g di pistacchi."
    },
    'Venerdì': {
        'Colazione': "Smoothie con 200 ml di latte scremato, 30 g di proteine in polvere, 1 banana, 1 cucchiaio di burro di mandorle.",
        'Spuntino di metà mattina': "200 g di yogurt greco magro con miele, 1 kiwi.",
        'Pranzo': "150 g di petto di pollo al curry, 200 g di riso integrale, verdure saltate (peperoni, cipolle).",
        'Spuntino pomeridiano': "1 mela, 30 g di mandorle.",
        'Cena': "200 g di gamberi saltati con aglio e peperoncino, 200 g di spaghetti integrali, verdure miste (spinaci, pomodorini).",
        'Spuntino serale': "200 ml di latte scremato, 2 fette biscottate integrali con 30 g di ricotta magra."
    },
    'Sabato': {
        'Colazione': "2 fette di pane integrale tostato, 2 uova in camicia, 1 avocado affettato, pomodoro a fette.",
        'Spuntino di metà mattina': "1 pera, 30 g di noci.",
        'Pranzo': "200 g di salmone al forno con erbe aromatiche, 250 g di patate dolci al forno, insalata mista.",
        'Spuntino pomeridiano': "1 barretta proteica, 1 yogurt magro.",
        'Cena': "200 g di tofu alla griglia, 200 g di riso integrale, verdure saltate (broccoli, carote, funghi).",
        'Spuntino serale': "200 ml di latte di mandorla, 30 g di anacardi."
    },
    'Domenica': {
        'Colazione': "Pancake integrali (100 g di farina integrale, 2 uova, 100 ml di latte scremato), topping di frutta fresca (frutti di bosco), 1 cucchiaio di miele.",
        'Spuntino di metà mattina': "1 panino integrale con 50 g di fesa di tacchino, verdure fresche.",
        'Pranzo': "200 g di bistecca di manzo alla griglia, 200 g di quinoa cotta, verdure grigliate (melanzane, zucchine).",
        'Spuntino pomeridiano': "200 g di yogurt greco magro con miele, ananas fresco.",
        'Cena': "200 g di zuppa di legumi (lenticchie, ceci, fagioli), 2 fette di pane integrale, insalata mista.",
        'Spuntino serale': "200 ml di latte scremato, 2 fette biscottate integrali con 30 g di burro di arachidi."
    }
}

# Creazione della lista dei pasti
for giorno, pasti in pasti_settimanali.items():
    for pasto, descrizione in pasti.items():
        piano_alimentare.append({
            'Giorno': giorno,
            'Pasto': pasto,
            'Descrizione': descrizione
        })

# Creazione del DataFrame per il piano alimentare
df_dieta = pd.DataFrame(piano_alimentare)

# Ordinamento per giorno e pasto
df_dieta['OrdineGiorni'] = df_dieta['Giorno'].map({
    'Lunedì': 1,
    'Martedì': 2,
    'Mercoledì': 3,
    'Giovedì': 4,
    'Venerdì': 5,
    'Sabato': 6,
    'Domenica': 7
})
df_dieta['OrdinePasti'] = df_dieta['Pasto'].map({
    'Colazione': 1,
    'Spuntino di metà mattina': 2,
    'Pranzo': 3,
    'Spuntino pomeridiano': 4,
    'Cena': 5,
    'Spuntino serale': 6
})
df_dieta = df_dieta.sort_values(['OrdineGiorni', 'OrdinePasti'])
df_dieta = df_dieta.drop(columns=['OrdineGiorni', 'OrdinePasti'])

# Salvataggio del piano alimentare in un file Excel
df_dieta.to_excel('dieta.xlsx', index=False)

# %%
# Creazione della lista della spesa
lista_spesa = []

# Dati per la lista della spesa
spesa = {
    'Frutta e Verdura': [
        {'Elemento': 'Banane', 'Quantità': '6'},
        {'Elemento': 'Mele', 'Quantità': '4'},
        {'Elemento': 'Pere', 'Quantità': '3'},
        {'Elemento': 'Kiwi', 'Quantità': '2'},
        {'Elemento': 'Avocado', 'Quantità': '4'},
        {'Elemento': 'Limoni', 'Quantità': '2'},
        {'Elemento': 'Frutti di bosco', 'Quantità': '500 g'},
        {'Elemento': 'Ananas', 'Quantità': '1'},
        {'Elemento': 'Pomodori', 'Quantità': '8'},
        {'Elemento': 'Spinaci freschi', 'Quantità': '1 confezione grande'},
        {'Elemento': 'Lattuga', 'Quantità': '1 cespo'},
        {'Elemento': 'Carote', 'Quantità': '1 kg'},
        {'Elemento': 'Zucchine', 'Quantità': '6'},
        {'Elemento': 'Melanzane', 'Quantità': '3'},
        {'Elemento': 'Peperoni', 'Quantità': '4'},
        {'Elemento': 'Broccoli', 'Quantità': '2 teste'},
        {'Elemento': 'Asparagi', 'Quantità': '1 mazzo'},
        {'Elemento': 'Funghi', 'Quantità': '300 g'},
        {'Elemento': 'Patate dolci', 'Quantità': '1 kg'},
        {'Elemento': 'Patate', 'Quantità': '1 kg'},
        {'Elemento': 'Cipolle', 'Quantità': '5'},
        {'Elemento': 'Aglio', 'Quantità': '1 testa'},
        {'Elemento': 'Prezzemolo fresco', 'Quantità': 'q.b.'},
        {'Elemento': 'Basilico fresco', 'Quantità': 'q.b.'},
        {'Elemento': 'Insalata mista', 'Quantità': '1 confezione'}
    ],
    'Proteine Animali': [
        {'Elemento': 'Petto di pollo', 'Quantità': '800 g'},
        {'Elemento': 'Petto di tacchino', 'Quantità': '500 g'},
        {'Elemento': 'Fesa di tacchino', 'Quantità': '200 g'},
        {'Elemento': 'Bresaola', 'Quantità': '200 g'},
        {'Elemento': 'Prosciutto crudo magro', 'Quantità': '200 g'},
        {'Elemento': 'Filetto di manzo', 'Quantità': '200 g'},
        {'Elemento': 'Bistecca di manzo', 'Quantità': '200 g'},
        {'Elemento': 'Salmone fresco', 'Quantità': '600 g'},
        {'Elemento': 'Merluzzo', 'Quantità': '200 g'},
        {'Elemento': 'Tonno fresco', 'Quantità': '200 g'},
        {'Elemento': 'Gamberi', 'Quantità': '200 g'},
        {'Elemento': 'Uova', 'Quantità': '12'},
        {'Elemento': 'Latte scremato', 'Quantità': '4 litri'},
        {'Elemento': 'Yogurt greco magro', 'Quantità': '1,5 kg'},
        {'Elemento': 'Ricotta magra', 'Quantità': '200 g'}
    ],
    'Proteine Vegetali': [
        {'Elemento': 'Tofu', 'Quantità': '400 g'},
        {'Elemento': 'Lenticchie', 'Quantità': '500 g'},
        {'Elemento': 'Ceci', 'Quantità': '200 g'},
        {'Elemento': 'Fagioli', 'Quantità': '200 g'},
        {'Elemento': 'Proteine in polvere', 'Quantità': '1 confezione'}
    ],
    'Carboidrati': [
        {'Elemento': 'Fiocchi d\'avena', 'Quantità': '500 g'},
        {'Elemento': 'Riso integrale', 'Quantità': '1 kg'},
        {'Elemento': 'Quinoa', 'Quantità': '500 g'},
        {'Elemento': 'Pasta integrale', 'Quantità': '500 g'},
        {'Elemento': 'Noodles integrali', 'Quantità': '200 g'},
        {'Elemento': 'Couscous integrale', 'Quantità': '200 g'},
        {'Elemento': 'Pane integrale', 'Quantità': '1 pagnotta'},
        {'Elemento': 'Fette biscottate integrali', 'Quantità': '1 confezione'},
        {'Elemento': 'Farina integrale', 'Quantità': '200 g'}
    ],
    'Grassi Sani e Condimenti': [
        {'Elemento': 'Olio d\'oliva extravergine', 'Quantità': '1 bottiglia'},
        {'Elemento': 'Burro di arachidi', 'Quantità': '200 g'},
        {'Elemento': 'Burro di mandorle', 'Quantità': '200 g'},
        {'Elemento': 'Mandorle', 'Quantità': '200 g'},
        {'Elemento': 'Noci', 'Quantità': '200 g'},
        {'Elemento': 'Anacardi', 'Quantità': '200 g'},
        {'Elemento': 'Pistacchi', 'Quantità': '200 g'},
        {'Elemento': 'Semi di chia o lino', 'Quantità': 'opzionale'}
    ],
    'Bevande': [
        {'Elemento': 'Latte di soia non zuccherato', 'Quantità': '1 litro'},
        {'Elemento': 'Latte di mandorla non zuccherato', 'Quantità': '1 litro'},
        {'Elemento': 'Acqua minerale', 'Quantità': 'quanto necessario'}
    ],
    'Varie': [
        {'Elemento': 'Miele', 'Quantità': '1 vasetto'},
        {'Elemento': 'Marmellata senza zuccheri aggiunti', 'Quantità': '1 vasetto'},
        {'Elemento': 'Salsa di soia a basso contenuto di sodio', 'Quantità': '1 bottiglia'},
        {'Elemento': 'Aceto balsamico', 'Quantità': '1 bottiglia'},
        {'Elemento': 'Salsa di pomodoro', 'Quantità': '2 barattoli'},
        {'Elemento': 'Pane per panini integrale', 'Quantità': '1 confezione'},
        {'Elemento': 'Barrette proteiche', 'Quantità': '6-7 pezzi'},
        {'Elemento': 'Spezie ed erbe aromatiche', 'Quantità': 'varie (sale, pepe, cannella, curry, paprika, origano, erbe di Provenza)'}
    ]
}

# Creazione della lista della spesa
for categoria, items in spesa.items():
    for item in items:
        lista_spesa.append({
            'Categoria': categoria,
            'Elemento': item['Elemento'],
            'Quantità': item['Quantità']
        })

# Creazione del DataFrame per la lista della spesa
df_spesa = pd.DataFrame(lista_spesa)

# Salvataggio della lista della spesa in un file Excel
df_spesa.to_excel('spesa.xlsx', index=False)
